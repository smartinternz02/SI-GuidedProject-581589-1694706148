# %% [markdown]
# # **AI ML Assignment 1**

# %% [markdown]
# ## Name: **SHREYA GUPTA**
# Campus: VIT **VELLORE**
#
# Registration Number: **21BCE0821**

# %% [markdown]
# **TASK - 1**

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(np.random.randint(1,100,size=(4,4)),columns=list('1234'))
df
# Out:
#     1   2   3   4
# 0  61  52  85   2
# 1  84  77  12  75
# 2  75  63  15  27
# 3  78   2   7  10

# %% [markdown]
# **TASK - 2**

# %%
df.rename(
columns = {'1':'Random value 1',
           '2':'Random value 2',
           '3':'Random value 3',
           '4':'Random value 4',
           },inplace=True
)
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0              61              52              85               2
# 1              84              77              12              75
# 2              75              63              15              27
# 3              78               2               7              10

# %% [markdown]
# **TASK - 3**

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000         4.00000        4.000000        4.000000
# mean        74.500000        48.50000       29.750000       28.500000
# std          9.746794        32.64455       36.980851       32.705759
# min         61.000000         2.00000        7.000000        2.000000
# 25%         71.500000        39.50000       10.750000        8.000000
# 50%         76.500000        57.50000       13.500000       18.500000
# 75%         79.500000        66.50000       32.500000       39.000000
# max         84.000000        77.00000       85.000000       75.000000

# %% [markdown]
# **TASK - 4**

# %%
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.dtypes
# Out:
# Random value 1    int64
# Random value 2    int64
# Random value 3    int64
# Random value 4    int64
# dtype: object

# %% [markdown]
#  **TASK - 5**

# %%
for column in ['Random value 2', 'Random value 3']:
  col_index=df.columns.get_loc(column)
  col_data=df[column].tolist()
  print(f"Column'{column}'(Index{col_index}):{col_data}")
# Out:
# Column'Random value 2'(Index1):[52, 77, 63, 2]
# Column'Random value 3'(Index2):[85, 12, 15, 7]
